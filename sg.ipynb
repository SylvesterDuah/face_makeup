# %% [markdown]
# <a href="https://colab.research.google.com/github/SylvesterDuah/face_makeup/blob/main/sg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Xiaojiu-z/Stable-Makeup.git
# %cd Stable-Makeup
# Out:
# fatal: destination path 'Stable-Makeup' already exists and is not an empty directory.
# /content/Stable-Makeup

# %%
# !ls
# Out:
# assets			gradio_demo_kps.py  pipeline_sd15.py  test_imgs
# datasets		infer_kps.py	    README.md	      train.py
# detail_encoder		LICENSE		    requirements.txt  train.sh
# diffusers_local_backup	models		    spiga_draw.py

# %%
# install the latest official diffusers (+ HF stack)…
# !pip install --upgrade diffusers transformers accelerate huggingface-hub

# …and pin PEFT to 0.6.2 so diffusers’ own version‐check passes
# !pip install peft==0.6.2

# %%
# !python infer_kps.py
# Out:
# 2025-04-30 17:59:41.093965: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746035981.137954    3596 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746035981.151275    3596 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-30 17:59:41.200260: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
